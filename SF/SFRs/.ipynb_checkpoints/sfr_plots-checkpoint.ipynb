# %%
# Preamble

from astropy.table import Table, column
import numpy as np
import os

# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
# better-looking plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['figure.figsize'] = (10.0, 8)
plt.rcParams['font.size'] = 18
mpl.ticker.AutoLocator.default_params['nbins'] = 5
mpl.ticker.AutoLocator.default_params['prune'] = 'both'

mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

# %%
import sys
sys.path.append('../../../astro_codes/')
#------------------------------------
from SFR_conversions import L_22_to_SFR, L_FUV_to_SFR
from luminosities_magnitudes_and_distances import Mag_to_lum, lum_to_solar

# %% [markdown]
# ## Load the required data

# %%
gz_data = Table.read('../matched_fits/gz_data.fits')
chang_in_matched = Table.read('../matched_fits/chang_in_matched.fits')
chang_out_matched = Table.read('../matched_fits/chang_out_matched.fits')
nsa_matched = Table.read('../matched_fits/nsa_matched.fits')
samples = Table.read('../matched_fits/samples.fits')
masks = Table.read('../matched_fits/bad_flux_mask.fits')
print('Loaded all data.')
# Out:
# Loaded all data.

# %% [markdown]
# ## Cut out the spiral sample

# %%
spiral_sample = ((samples['in_mass_limit']) &
                 (samples['in_spiral']) &
                 (samples['axial_ok']))

ml_sample = (samples['in_mass_limit'])

# %%
w4_lums = chang_out_matched['lrest_w4']

fuv_mags = nsa_matched['M_corrected'][:,0]
fuv_lums = Mag_to_lum(fuv_mags,1538.62)
fuv_lums = lum_to_solar(fuv_lums)

sfr_uv = L_FUV_to_SFR(fuv_lums,input_log=True)
sfr_ir = L_22_to_SFR(w4_lums,input_log=True)
sfr_total = np.log10(10**(sfr_ir) + 10**(sfr_uv))
# Out:
# ../../../astro_codes/luminosities_magnitudes_and_distances.py:35: RuntimeWarning: overflow encountered in power
#   S = 3631*10**(Mag/-2.5)*u.Jy # AB -> flux density
# ../../../astro_codes/SFR_conversions.py:16: RuntimeWarning: divide by zero encountered in log10
#   return np.log10(sfr)

# %%
sfr_table = Table(np.array([sfr_uv,sfr_ir,sfr_total]).T,names=('uv','ir','total'))
sfr_table.write('../matched_fits/sfr_table.fits',overwrite=True)

# %%
'''
fuv_mags = nsa_matched['M_corrected'][:,0]
fuv_flux = nsa_matched['PETROFLUX'][:,0]
fuv_flux_error = (nsa_matched['PETROFLUX_IVAR'][:,0])**(-1/2)
fuv_snr = fuv_flux/fuv_flux_error

w3_lums = chang_out_matched['lrest_w3']
w3_flux = chang_in_matched['flux_w3']
w3_flux_error = chang_in_matched['flux_w3_e']
w3_snr = w3_flux/w3_flux_error

w4_lums = chang_out_matched['lrest_w4']
w4_flux = chang_in_matched['flux_w4']
w4_flux_error = chang_in_matched['flux_w4_e']
w4_snr = w4_flux/w4_flux_error

has_w4 = masks['w4']
has_w3 = (masks['w3']) & (masks['w4'] == False)
has_fuv = (masks['fuv'])

sfr_fuv, sfr_fuv_error = FUV_to_sfr(fuv_mags,snr=fuv_snr)
sfr_w3, sfr_w3_error = L12_to_sfr(w3_lums,snr=w3_snr)
sfr_w4, sfr_w4_error = L22_to_sfr(w4_lums,snr=w4_snr)

sfr_fuv[has_fuv == False] = -999
sfr_fuv_error[has_fuv == False] = -999

sfr_ir = sfr_w4.copy()
sfr_ir[has_w3] = sfr_w3[has_w3]
sfr_ir[(has_w3 == False) & (has_w4 == False)] = -999

sfr_ir_error = sfr_w4_error.copy()
sfr_ir_error[has_w3] = sfr_w3_error[has_w3]
sfr_ir_error[(has_w3 == False) & (has_w4 == False)] = -999

sfr_table = Table()
sfr_table['fuv'] = sfr_fuv
sfr_table['fuv_error'] = sfr_fuv_error
sfr_table['nir'] = sfr_ir
sfr_table['nir_error'] = sfr_ir_error
'''
# Out:
# "\nfuv_mags = nsa_matched['M_corrected'][:,0]\nfuv_flux = nsa_matched['PETROFLUX'][:,0]\nfuv_flux_error = (nsa_matched['PETROFLUX_IVAR'][:,0])**(-1/2)\nfuv_snr = fuv_flux/fuv_flux_error\n\nw3_lums = chang_out_matched['lrest_w3']\nw3_flux = chang_in_matched['flux_w3']\nw3_flux_error = chang_in_matched['flux_w3_e']\nw3_snr = w3_flux/w3_flux_error\n\nw4_lums = chang_out_matched['lrest_w4']\nw4_flux = chang_in_matched['flux_w4']\nw4_flux_error = chang_in_matched['flux_w4_e']\nw4_snr = w4_flux/w4_flux_error\n\nhas_w4 = masks['w4']\nhas_w3 = (masks['w3']) & (masks['w4'] == False)\nhas_fuv = (masks['fuv'])\n\nsfr_fuv, sfr_fuv_error = FUV_to_sfr(fuv_mags,snr=fuv_snr)\nsfr_w3, sfr_w3_error = L12_to_sfr(w3_lums,snr=w3_snr)\nsfr_w4, sfr_w4_error = L22_to_sfr(w4_lums,snr=w4_snr)\n\nsfr_fuv[has_fuv == False] = -999\nsfr_fuv_error[has_fuv == False] = -999\n\nsfr_ir = sfr_w4.copy()\nsfr_ir[has_w3] = sfr_w3[has_w3]\nsfr_ir[(has_w3 == False) & (has_w4 == False)] = -999\n\nsfr_ir_error = sfr_w4_error.
# ...

# %% [markdown]
# ## Calculate the total SFR (NIR+FUV)

# %%
import matplotlib.gridspec as gridspec
from contours import kde_contour

def make_figure(xlabel='x', ylabel='y'):
    fig = plt.figure(figsize=(10,10))
    gs = gridspec.GridSpec(3,3)
    ax0 = plt.subplot(gs[0,0:2])
    ax1 = plt.subplot(gs[1:,2])
    ax2 = plt.subplot(gs[1:,0:2])
    axarr = [ax0, ax1, ax2]
    plt.subplots_adjust(hspace=0,wspace=0)
    if xlabel != None:
        axarr[2].set_xlabel(xlabel)
    if ylabel != None:
        axarr[2].set_ylabel(ylabel)
    axarr[0].set_xticks([])
    axarr[0].set_yticks([])
    axarr[1].set_xticks([])
    axarr[1].set_yticks([])
    return fig, axarr


def histogram(data,bins,fill_properties,line_properties,
              fill=False,weights=None,normed=True,orientation='horizontal'):
    
    if fill == True:
        _ = plt.hist(data,bins,normed=normed,histtype='stepfilled',
                     weights=weights,orientation=orientation,
                     color=fill_properties['color'],
                     alpha=fill_properties['alpha'])
    
    _ = plt.hist(data,bins,normed=normed,histtype='step',
                 weights=weights,orientation=orientation,
                 color=line_properties['color'],
                 linewidth=line_properties['linewidth'],
                 linestyle=line_properties['linestyle'],
                 alpha=line_properties['alpha'])
    return None


def compare_xy_data(x,y,xy_range,N_bins,weights=None,xlabel='x',ylabel='y',
                    fill=False,contour_fill_properties=None,axarr=None,fig=None,
                    hist_fill_properties=None,line_properties=None,
                    bandwidth=None,levels=[0.2,0.4,0.6,0.8]):
    
    xmin, xmax, ymin, ymax = xy_range
    
    if xy_range == None:
        x_hist = x
        y_hist = y
        x_contour = x
        y_contour = y
        w_x, w_y, w_c = [weights, weights, weights]
    else:
        x_ok = (x >= xmin) & (x <= xmax)
        y_ok = (y >= ymin) & (y <= ymax)
        x_hist = x[x_ok]
        y_hist = y[y_ok]
        x_contour = x[(x_ok) & (y_ok)]
        y_contour = y[(x_ok) & (y_ok)]
        if weights != None:
            w_x = weights[x_ok]
            w_y = weights[y_ok]
            w_c = weights[(x_ok) & (y_ok)]
        else:
            w_x, w_y, w_c = [None,None,None]
    
    c_fp = {'colormap':'Greys',
           'alpha':0.5}  

    h_fp = {'color':'k',
            'alpha':0.5}
    
    lp = {'color':'k',
          'alpha':1,
          'linewidth':1,
          'linestyle':'solid'}
    
    if line_properties != None:
        for l in line_properties.keys():
            lp[l] = line_properties[l]
    if hist_fill_properties != None:
        for f in hist_fill_properties.keys():
            h_fp[f] = hist_fill_properties[f]
    if contour_fill_properties != None:
        for f in contour_fill_properties.keys():
            c_fp[f] = contour_fill_properties[f]
    
    x_bins = np.linspace(xy_range[0],xy_range[1],N_bins[0]+1)
    y_bins = np.linspace(xy_range[2],xy_range[3],N_bins[1]+1)
    
    if axarr == None:
        fig, axarr = make_figure(xlabel,ylabel)
    
    plt.sca(axarr[0])
    _ = histogram(x_hist,x_bins,h_fp,lp,fill,weights=w_x,orientation='vertical')
    plt.sca(axarr[1])
    _ = histogram(y_hist,y_bins,h_fp,lp,fill,weights=w_y)
    plt.sca(axarr[2])
    #_ = plt.scatter(x_contour,y_contour,alpha=0.01)
    _ = kde_contour(x_contour,y_contour,xy_range,bandwidth,fill,c_fp,lp,levels,weights=w_c)
    bandwidth = _[-1]
    
    axarr[0].set_xlim(xmin,xmax)
    axarr[1].set_ylim(ymin,ymax)
    axarr[2].axis((xmin,xmax,ymin,ymax))
    
    return fig, axarr, bandwidth

# %%
colors = ['orange','r','m','g','b']
m_labels = ['1','2','3','4','5+']
f_labels = 'abcde'
xy_range = (-12,-9,-12,-9)
N_bins = (30,30)

masses = chang_out_matched['lmass50_all']
ssfr_nir = sfr_table['ir'] - masses
ssfr_fuv = sfr_table['uv'] - masses

# Create masks for the different datasets:
ml_all = samples['in_mass_limit']
ml_spirals = ((samples['in_mass_limit']) & 
              (samples['in_spiral']) & 
              (samples['axial_ok']))
fuv_ok = masks['fuv']
nir_ok = masks['w4']

reference_mask = (ml_all) & (fuv_ok) & (nir_ok)

x_ref, y_ref = ssfr_nir[reference_mask], ssfr_fuv[reference_mask]

# Plotting paramaters
reference_contour_fill = {'colormap':'Greys',
                          'alpha':1}

reference_hist_fill = {'color':'k',
                       'alpha':0.4}
#####################
spiral_ok = (ml_spirals) & (fuv_ok) & (nir_ok)

bw = None
for m in range(5):
    
    m_ok = samples['m'] == m
    m_mask = (m_ok) & (spiral_ok)
    x, y = ssfr_nir[m_mask], ssfr_fuv[m_mask]

    fig, axarr, bw = compare_xy_data(x_ref,y_ref,xy_range,N_bins,bandwidth=bw,
                                     fill=True,contour_fill_properties=reference_contour_fill,
                                     hist_fill_properties=reference_hist_fill,
                                     xlabel='$\mathrm{SSFR_{NIR}} \, (\log{\mathrm{yr^{-1}}})$',
                                     ylabel='$\mathrm{SSFR_{FUV}} \, (\log{\mathrm{yr^{-1}}})$')
    
    line_properties = {'color':colors[m],
                       'linewidth':2.5}
    
    _ = compare_xy_data(x,y,xy_range,N_bins,fig=fig,axarr=axarr,
                        fill=False,line_properties=line_properties)
    
    # indicate medians?
    median_x = np.median(x)
    median_y = np.median(y)
    print(median_x,median_y)
    
    ref_line = axarr[-1].plot([], [], color='k',linewidth=1,
                              label='All galaxies ($N_\mathrm{{gal}}$={})'.format(len(x_ref)))
    data_line = axarr[-1].plot([],[],color=colors[m],linewidth=2,
                               label='m={} ($N_\mathrm{{gal}}$={})'.format(m_labels[m],len(x)))
    
    axarr[-1].hlines(median_y,xy_range[0],xy_range[1],color=colors[m],lw=1)
    axarr[-1].vlines(median_x,xy_range[2],xy_range[3],color=colors[m],lw=1)
    
    axarr[-1].legend(fontsize=15)
    axarr[-1].text(0.05,0.95,'({})'.format(f_labels[m]),
             transform=axarr[-1].transAxes,ha='left',va='top')
    fig.savefig('../output_figures/m_{}_ssfr_comparison.pdf'.format(m))
# Out:
# -10.4653350688 -10.8252654783
# -10.5851447151 -10.8841520063
# -10.549665785 -10.7305494062
# -10.6139812904 -10.7279395811
# -10.7501744602 -10.7309779874

# %%
colors = ['orange','r','m','g','b']
m_labels = ['1','2','3','4','5+']
f_labels = 'abcde'
xy_range = (-12,-9,-12,-9)
N_bins = (30,30)

masses = chang_out_matched['lmass50_all']
ssfr_nir = sfr_table['ir'] - masses
ssfr_fuv = sfr_table['uv'] - masses

# Create masks for the different datasets:
ml_all = samples['in_mass_limit']
ml_spirals = ((samples['in_mass_limit']) & 
              (samples['in_spiral']) & 
              (samples['axial_ok']) & 
              (samples['unbarred']))
fuv_ok = masks['fuv']
nir_ok = masks['w4']

reference_mask = (ml_all) & (fuv_ok) & (nir_ok)

x_ref, y_ref = ssfr_nir[reference_mask], ssfr_fuv[reference_mask]

# Plotting paramaters
reference_contour_fill = {'colormap':'Greys',
                          'alpha':1}

reference_hist_fill = {'color':'k',
                       'alpha':0.4}
#####################
spiral_ok = (ml_spirals) & (fuv_ok) & (nir_ok)

bw = None
for m in range(5):
    
    m_ok = samples['m'] == m
    m_mask = (m_ok) & (spiral_ok)
    x, y = ssfr_nir[m_mask], ssfr_fuv[m_mask]

    fig, axarr, bw = compare_xy_data(x_ref,y_ref,xy_range,N_bins,bandwidth=bw,
                                     fill=True,contour_fill_properties=reference_contour_fill,
                                     hist_fill_properties=reference_hist_fill,
                                     xlabel='$\mathrm{SSFR_{NIR}} \, (\log{\mathrm{yr^{-1}}})$',
                                     ylabel='$\mathrm{SSFR_{FUV}} \, (\log{\mathrm{yr^{-1}}})$')
    
    line_properties = {'color':colors[m],
                       'linewidth':2.5}
    
    _ = compare_xy_data(x,y,xy_range,N_bins,fig=fig,axarr=axarr,
                        fill=False,line_properties=line_properties)
    
    ref_line = axarr[-1].plot([], [], color='k',linewidth=1,label='All galaxies (N={})'.format(len(x_ref)))
    data_line = axarr[-1].plot([],[],color=colors[m],linewidth=2,label='m={} (N={})'.format(m_labels[m],len(x)))
    axarr[-1].legend(fontsize=15)
    axarr[-1].text(0.05,0.95,'({})'.format(f_labels[m]),
             transform=axarr[-1].transAxes,ha='left',va='top')
    #fig.savefig('../output_figures/m_{}_ssfr_comparison.pdf'.format(m))

# %%
from scipy.stats import binned_statistic
from astroML.resample import bootstrap

def plot_line(x,y,bins=12,plot=True,fill=False,color='k',ranges=None,use_bootstrap=False):
    
    def percentiles(x):
        lower = np.percentile(x,16)
        median = np.median(x)
        upper = np.percentile(x,84)
        return lower, median, upper
    
    if ranges == None:
        ranges = (np.min(x),np.max(x),np.min(y),np.max(y))
        
    if isinstance(bins, int) == True:
        bins = np.linspace(ranges[0],ranges[1],bins+1)
    x_bins, _, bin_assignment = binned_statistic(x,x,bins=bins,statistic='median')
    
    x_medians = np.array([])
    x_uppers = np.array([])
    x_lowers = np.array([])
    y_medians = np.array([])
    y_uppers = np.array([])
    y_lowers = np.array([])
    for b in np.unique(bin_assignment):
        in_bin = bin_assignment == b
        x_bin = x[in_bin]
        y_bin = y[in_bin]
        
        if use_bootstrap == True:
            x_lower, x_median, x_upper = bootstrap(x_bin,10,percentiles,random_state=0)
            y_lower, y_median, y_upper = bootstrap(y_bin,10,percentiles,random_state=0)
        else:
            x_lower, x_median, x_upper = percentiles(x_bin)
            y_lower, y_median, y_upper = percentiles(y_bin)
        
        x_lowers = np.append(x_lowers,x_lower)
        x_medians = np.append(x_medians,x_median)
        x_uppers = np.append(x_uppers,x_upper)
        y_lowers = np.append(y_lowers,y_lower)
        y_medians = np.append(y_medians,y_median)
        y_uppers = np.append(y_uppers,y_upper)
    
    if plot == True:
        _ = plt.plot(x_medians, y_medians,color=color,lw=3)
        if fill == True:
            _ = plt.fill_between(x_medians,y_lowers,y_uppers,color=color,alpha=0.4)
        else:
            _ = plt.plot(x_medians,y_lowers,linestyle='dashed',linewidth=1.5,color=color)
            _ = plt.plot(x_medians,y_uppers,linestyle='dashed',linewidth=1.5,color=color)
            
    stats_table = Table()
    stats_table['x'] = x_medians
    stats_table['x_upper'] = x_uppers
    stats_table['x_lower'] = x_lowers
    stats_table['y'] = y_medians
    stats_table['y_upper'] = y_uppers
    stats_table['y_lower'] = y_lowers
    
    return stats_table, bins

# %%
fig, axarr = plt.subplots(1,5,figsize=(20,4),sharex=True,sharey=True)
plt.subplots_adjust(hspace=0,wspace=0)
axarr = axarr.ravel()
#fig.delaxes(axarr[-1])

xy_range = (10.25,11.25,-0.5,1.5)

masses = chang_out_matched['lmass50_all']
sfr_total = sfr_table['total']

# Create masks for the different datasets:
ml_all = samples['in_mass_limit']
ml_spirals = (samples['in_mass_limit']) & (samples['in_spiral']) & (samples['axial_ok'])
fuv_ok = masks['fuv']
nir_ok = masks['w4']

reference_mask = (ml_all) & (fuv_ok) & (nir_ok)

x_ref, y_ref = masses[reference_mask], sfr_total[reference_mask]

#####################
spiral_ok = (ml_spirals) & (fuv_ok) & (nir_ok)

bins = np.linspace(xy_range[0],xy_range[1],8)

for m in range(5):
    plt.sca(axarr[m])
    
    m_ok = samples['m'] == m
    m_mask = (m_ok) & (spiral_ok)
    x, y = masses[m_mask], sfr_total[m_mask]
    
    _ = plot_line(x_ref,y_ref,bins,color='k',fill=True,use_bootstrap=True)
    _ = plot_line(x,y,bins,color=colors[m],fill=False,use_bootstrap=True)
    
    ref_line = axarr[m].plot([], [], color='k',linewidth=3,label='All galaxies (N={})'.format(len(x_ref)))
    data_line = axarr[m].plot([],[],color=colors[m],linewidth=3,label='m={} (N={})'.format(m_labels[m],len(x)))
    axarr[m].legend(fontsize=15)
    axarr[m].text(0.05,0.95,'({})'.format(f_labels[m]),
                  transform=axarr[m].transAxes,ha='left',va='top')
    axarr[m].set_xlabel('$\mathrm{\log{(M_*/M_{\odot})}}$')
    
_ = plt.axis(xy_range)
axarr[0].set_ylabel('$\mathrm{SFR_{total} \, (M_{\odot} yr^{-1})}$')

#fig.add_subplot(111, frameon=False)
#plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')
#plt.xlabel('$\mathrm{\log{(M_*/M_{\odot})}}$')
#plt.ylabel('$\mathrm{SFR \, (M_{\odot} yr^{-1})}$')
#plt.tight_layout()

fig.savefig('../output_figures/sfms_comparison.pdf')

# %% [markdown]
# ## Calculate luminosities rather than SFRs?

# %%
import astropy.units as u
def angstrom_to_hz(wavelength):
    wavelength = wavelength*(u.Angstrom)#
    wavelength = wavelength.to(u.m)
    c = 3e8*(u.m/u.s)
    mu = c/wavelength
    return mu.value

fuv_mags = nsa_matched['M_corrected'][:,0]
nuv_mags = nsa_matched['M_corrected'][:,1]


fuv_mu = angstrom_to_hz(1538.62)*u.Hz
nuv_mu = angstrom_to_hz(2315.66)*u.Hz

fuv_lums = Mag_to_lum(fuv_mags)*fuv_mu
nuv_lums = Mag_to_lum(nuv_mags)*fuv_mu

solar_luminosity = 3.828e33*(u.erg/u.s)

fuv_lums, nuv_lums = [np.log10(l/solar_luminosity).value for l in [fuv_lums,nuv_lums]]

w3_lums, w4_lums = chang_out_matched['lrest_w3'], chang_out_matched['lrest_w4']

lum_table = Table()
lum_table['fuv'] = fuv_lums
lum_table['nuv'] = nuv_lums
lum_table['w3'] = w3_lums
lum_table['w4'] = w4_lums

# %%
xy_range = (-0.4,0.4,-1.5,1.5)
N_bins = (30,30)

masses = chang_out_matched['lmass50_all']
log_fuv_nuv = lum_table['fuv'] - lum_table['nuv'] + 0.177 # L_lambda
log_nir_fuv = lum_table['w4'] - lum_table['fuv'] 

# Create masks for the different datasets:
ml_all = samples['in_mass_limit']
ml_spirals = (samples['in_mass_limit']) & (samples['in_spiral']) & (samples['axial_ok'])
fuv_ok = masks['fuv']
nuv_ok = masks['nuv']
nir_ok = masks['w4']

reference_mask = (ml_all) & (fuv_ok) & (nuv_ok) & (nir_ok) 

x_ref, y_ref = log_fuv_nuv[reference_mask], log_nir_fuv[reference_mask]

# Plotting paramaters
reference_contour_fill = {'colormap':'Greys',
                          'alpha':1}

reference_hist_fill = {'color':'k',
                       'alpha':0.4}
#####################
spiral_ok = (ml_spirals) & (fuv_ok) & (nir_ok)

bw = None
for m in range(5):
    
    m_ok = samples['m'] == m
    m_mask = (m_ok) & (spiral_ok)
    x, y = log_fuv_nuv[m_mask], log_nir_fuv[m_mask]

    fig, axarr, bw = compare_xy_data(x_ref,y_ref,xy_range,N_bins,bandwidth=bw,
                                     fill=True,contour_fill_properties=reference_contour_fill,
                                     hist_fill_properties=reference_hist_fill,
                                     xlabel='$\mathrm{\log(L_{FUV}/L_{NUV})}$',
                                     ylabel='$\mathrm{\log(L_{22}/L_{FUV})}$')
    
    line_properties = {'color':colors[m],
                       'linewidth':2.5}
    
    _ = compare_xy_data(x,y,xy_range,N_bins,fig=fig,axarr=axarr,
                        fill=False,line_properties=line_properties)
    
    ref_line = axarr[-1].plot([], [], color='k',linewidth=1,label='All galaxies (N={})'.format(len(x_ref)))
    data_line = axarr[-1].plot([],[],color=colors[m],linewidth=2,label='m={} (N={})'.format(m_labels[m],len(x)))
    axarr[-1].legend(fontsize=15)
    axarr[-1].text(0.05,0.95,'({})'.format(f_labels[m]),
             transform=axarr[-1].transAxes,ha='left',va='top')
    
    axarr[0].invert_xaxis()
    axarr[2].invert_xaxis()
    
    #fig.savefig('../output_figures/m_{}_ssfr_comparison.pdf'.format(m))

# %% [markdown]
# ## 'Other' paramaters???

# %%
A_v = nsa_matched['AV']
has_A_v = A_v > 0

mu = chang_out_matched['mu50_all']
has_mu = mu > 0
#mu_error = (chang_out_matched['mu84_all'] - chang_out_matched['mu16_all'])/2
tau_v = chang_out_matched['tau_v50_all']
#tau_error = (chang_out_matched['tau_v84_all'] - chang_out_matched['tau_v16_all'])
has_tau = tau_v > 0

d4000 = nsa_matched['D4000']
d4000_error = nsa_matched['D4000ERR']
has_d4000 = d4000/d4000_error > 2

# %%
def comparison_histogram(data,reference,bins,m_values,xlabel='x',reference_2=None):
    
    colors = ['orange','r','m','g','b']
    labels = ['1','2','3','4','5+']
    
    fig, axarr = plt.subplots(5,1,figsize=(10,15),sharex=True,sharey=True)
    plt.subplots_adjust(wspace=0,hspace=0)
    
    for m in range(5):
        m_data = data[m_values == m]
        _ = axarr[m].hist(reference,color='k',alpha=0.4,bins=bins,
                          histtype='stepfilled',normed=True,zorder=0,
                          label='All spirals (N={})'.format(len(reference)))
        _ = axarr[m].hist(m_data,color=colors[m],lw=2.5,bins=bins,
                          histtype='step',normed=True,zorder=2,
                          label='m={} (N={})'.format(m_labels[m],len(m_data)))
        if reference_2 != None:
            _ = axarr[m].hist(reference_2,color='k',lw=1.5,bins=bins,
                              histtype='step',normed=True,zorder=1,
                              label='All galaxies (N={})'.format(len(reference_2)))
        axarr[m].legend(fontsize=10)
        axarr[m].set_ylabel('normalised \n density')
        
    axarr[-1].set_xlim(bins[0],bins[-1])
    
    axarr[-1].set_xlabel(xlabel)
    return None

# %%
params = [d4000,A_v,mu,tau_v]
masks_p = [has_d4000,has_A_v,has_mu,has_tau]
labels = ['$\mathrm{D_n 4000}$','$\mathrm{A_v}$',r'$\mathrm{\nu}$',r'$\mathrm{\tau_{\nu}}$']
m_values = samples['m']
ranges = [(1,2.2),(0,4),(0,0.5),(0,4)]

ml_all = samples['in_mass_limit']
ml_spirals = (samples['in_mass_limit']) & (samples['in_spiral']) & (samples['axial_ok'])

for p in range(4):
    
    bins = np.linspace(ranges[p][0],ranges[p][1],51)
    reference_mask = (ml_spirals) & (masks_p[p])
    reference_2_mask = (ml_all) & (masks_p[p])
    data_mask = (ml_spirals) & (masks_p[p])
    
    reference = params[p][reference_mask]
    data, m_values_p = (params[p][data_mask], m_values[data_mask])
    reference_2 = params[p][reference_2_mask]
    comparison_histogram(reference,data,bins,m_values_p,labels[p],
                         reference_2=reference_2)

# %% [markdown]
# ## IRX-$\beta$ relationship

# %%
# IRX = infra-red excess
# beta = UV 'slope'
ok_all = masks['fuv']*masks['nuv']*masks['w4'].astype(bool)

lambda_fuv = 1538.62
lambda_nuv = 2315.66

def calculate_beta(Mag_fuv,Mag_nuv,lambda_fuv=1538.2,lambda_nuv=2315.66):
    beta = (Mag_nuv-Mag_fuv)/(2.5*np.log10(lambda_fuv/lambda_nuv)) - 2
    return beta

def calculate_irx(L_dust,L_fuv,log=True):
    if log == True:
        irx = L_dust - L_fuv
    else:
        irx = L_dust/L_fuv
    return irx

beta = calculate_beta(nsa_matched['M_corrected'][:,0],nsa_matched['M_corrected'][:,1])
irx = calculate_irx(lum_table['w4'],lum_table['fuv'])

# %%
xy_range = (-1.5,1,-2,1.5)
N_bins = (30,30)

masses = chang_out_matched['lmass50_all']

# Create masks for the different datasets:
ml_all = samples['in_mass_limit']
ml_spirals = (samples['in_mass_limit']) & (samples['in_spiral']) & (samples['axial_ok'])
fuv_ok = masks['fuv']
nuv_ok = masks['nuv']
nir_ok = masks['w4']

reference_mask = (ml_all) & (fuv_ok) & (nuv_ok) & (nir_ok) 

x_ref, y_ref = beta[reference_mask], irx[reference_mask]

# Plotting paramaters
reference_contour_fill = {'colormap':'Greys',
                          'alpha':1}

reference_hist_fill = {'color':'k',
                       'alpha':0.4}
#####################
spiral_ok = (ml_spirals) & (fuv_ok) & (nir_ok)

bw = None
for m in range(5):
    
    m_ok = samples['m'] == m
    m_mask = (m_ok) & (spiral_ok)
    x, y = beta[m_mask], irx[m_mask]

    fig, axarr, bw = compare_xy_data(x_ref,y_ref,xy_range,N_bins,bandwidth=bw,
                                     fill=True,contour_fill_properties=reference_contour_fill,
                                     hist_fill_properties=reference_hist_fill,
                                     xlabel=r'$\mathrm{\beta}$',
                                     ylabel='$\mathrm{IRX}$')
    
    line_properties = {'color':colors[m],
                       'linewidth':2.5}
    
    _ = compare_xy_data(x,y,xy_range,N_bins,fig=fig,axarr=axarr,
                        fill=False,line_properties=line_properties)
    
    ref_line = axarr[-1].plot([], [], color='k',linewidth=1,label='All galaxies (N={})'.format(len(x_ref)))
    data_line = axarr[-1].plot([],[],color=colors[m],linewidth=2,label='m={} (N={})'.format(m_labels[m],len(x)))
    axarr[-1].legend(fontsize=15)
    axarr[-1].text(0.05,0.95,'({})'.format(f_labels[m]),
             transform=axarr[-1].transAxes,ha='left',va='top')
    
    #fig.savefig('../output_figures/m_{}_ssfr_comparison.pdf'.format(m))
